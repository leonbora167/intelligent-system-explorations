# %%
import cv2
import torch 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model = torch.hub.load("ultralytics/yolov5", "custom", path="yolov5l.pt")
# Out:
# Using cache found in /home/leon/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-6-2 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2060, 5935MiB)
#
# Fusing layers...
# YOLOv5l summary: 367 layers, 46533693 parameters, 0 gradients
# Adding AutoShape...

# %%
img = cv2.imread("test.png")
plt.imshow(img)

# %%
results = model(img)
bboxes = results.pandas().xyxy[0]

# %%
# 	1152.906250 	477.808319 	1250.568726 	534.508911
img = cv2.imread("test.png")
x1, y1 = 1006,713
x2, y2 = 1165,888
cv2.rectangle(img, (x1,y1), (x2,y2), (0,255,255), 4)
plt.imshow(img)

# %%
#That car is a swift dzire
#The width of this car is 
#3,995 mm L x 1,735 mm W x 1,515 mm H

# %% [markdown]
# Height of target Car = 3995mm = 3.995m
# Height of Bounding box = 888 - 713 = 175px
#
# 3.995m/175px = 0.02282
# Round of the pixels by 25 to round off for perspective correction
# 3.995m/150px = 0.02663
#
# for every 1px in the image, it covers a distance of 0.02663
#
# Therefore, pixel_meter_ratio = 0.02663
