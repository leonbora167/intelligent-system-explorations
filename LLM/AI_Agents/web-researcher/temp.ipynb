# %%
from ddgs import DDGS
from trafilatura import fetch_url, extract, sitemaps
from trafilatura.spider import focused_crawler
import requests 
from bs4 import BeautifulSoup
from playwright.sync_api import sync_playwright

# %% [markdown]
# # Link Retrieval

# %%
#Textual retrieval
query = "Lego Batman 2026 game"

results = DDGS().text(query, 
                      safesearch = "off",
                      backend = "auto",
                      max_results=5)

# %%
results
# Out:
# [{'title': 'Lego Batman: Legacy of the Dark Knight - Wikipedia',
#   'href': 'https://en.wikipedia.org/wiki/Lego_Batman:_Legacy_of_the_Dark_Knight',
#   'body': "1 week ago - It is the fourth installment in the Lego Batman video game series, and features an original story inspired by comic books, films and other media from the Batman franchise. Legacy of the Dark Knight uses Unreal Engine 5 as opposed to TT Games' proprietary game engine, and takes heavy inspiration from Batman: Arkham, another series of Batman video games. Announced at Gamescom in 2025, it was released on PlayStation 5, Windows, and Xbox Series X/S on May 22, 2026..."},
#  {'title': 'LEGO® Batman™: Legacy of the Dark Knight',
#   'href': 'https://www.lego.com/en-us/games/lego-batman-legacy-dark-knight',
#   'body': 'LEGO Batman: Legacy of the Dark Knight will be available on PlayStation®5, Xbox Series X|S, Nintendo Switch™ 2, and PC (Steam and Epic Games Store). LEGO Batman: Legacy of the Dark Knight is scheduled to launch on May 22, 2026, for PlayStation ...'},
#  {'title': 'LEGO Batman: Legacy of the Dark Knight (Video Game 2026) | Action, Adventure, Family',
#   'href': 'https://www.imdb.com/title/tt37976258/',
#   'body': 'May 29, 2026 - Video Game · 2026 · E10+ ActionAdventureFamilyFantasy · Inspired by decades of Batman media; "LEGO Batman: Legacy of the Dark Knight" is a new open-world action adventure video game that invites players to explore Bruce Wayne\'s epic journey ...'},
#  {'title': 'LEGO® Batman',
#   'href': 'https://www.lego.com/en-in/games/lego-batman-legacy-dark-knight',
#   'body': 'Become the Dark Knight in an open-world LEGO action adventure from TT Games, the award-winning studio behind LEGO Star Wars: The Skywalker Saga™. Battle Gotham City’s most notorious Super-Villains and relive the journey of Batman™ from ...'},
#  {'title': 'LEGO® Batman™: Legacy of The Dark Knight',
#   'href': 'https://legobatmangame.com/',
#   'body': 'Mayhem Collection is a separate post-launch DLC releasing September 18, 2026 and will be included in the LEGO® Batman™: Legacy of the Dark Knight Deluxe Edition (full base game required).'}]

# %% [markdown]
# # Read/Extract data from link

# %%
web_url = results[0]["href"]
downloaded = fetch_url(web_url)
print(web_url)
# Out:
# https://en.wikipedia.org/wiki/Lego_Batman:_Legacy_of_the_Dark_Knight

# %%
#plain text output 

result = extract(downloaded)
print(result[0:100])
# Out:
# Lego Batman: Legacy of the Dark Knight
# | Lego Batman: Legacy of the Dark Knight |  |
# |---|---|
# | De

# %%
# XML Format, to preserver doc structure ?
xml_result = extract(downloaded, output_format="xml")

# Json format
json_result = extract(downloaded, output_format="json", with_metadata=True, include_comments=True)

# Markdown format 
markdown_result = extract(downloaded, output_format="markdown", with_metadata=True)

# %% [markdown]
# # BS4 Parser

# %%
html_content_file = "page_content.html"
with open(html_content_file, "r", encoding="utf-8") as f:
    html_content = f.read() 
soup = BeautifulSoup(html_content, "html.parser")

page_main_title = soup.title.string
# Out:
# 'Lego Batman: Legacy of the Dark Knight - Wikipedia'

# %%
import requests
r = requests.get("https://kotaku.com", timeout=10, headers={"User-Agent": "Mozilla/5.0"})
print(r.status_code)
# Out:
# 200
