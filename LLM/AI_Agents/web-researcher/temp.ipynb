# %%
from ddgs import DDGS

# %%
from readline import backend


query = "Lego Batman 2026"

results = DDGS().text(query, 
                      safesearch = "off",
                      backend = "wikipedia"
                      max_results=5)
# Out:
# [{'title': 'Lego Batman: Legacy of the Dark Knight - Wikipedia', 'href': 'https://en.wikipedia.org/wiki/Lego_Batman:_Legacy_of_the_Dark_Knight', 'body': "5 days ago - It is the fourth installment in the Lego Batman video game series, and features an original story inspired by comic books, films and other media from the Batman franchise. Legacy of the Dark Knight uses Unreal Engine 5 as opposed to TT Games' proprietary game engine, and takes heavy inspiration from Batman: Arkham, another series of Batman video games. Announced at Gamescom in 2025, it was released on PlayStation 5, Windows, and Xbox Series X/S on May 22, 2026..."}, {'title': 'LEGO Batman: Legacy of the Dark Knight (Video Game 2026) | Action, Adventure, Family', 'href': 'https://www.imdb.com/title/tt37976258/', 'body': '2 weeks ago - LEGO Batman: Legacy of the Dark Knight: With Matt Berry, Shai Matheson. Inspired by decades of Batman media; "LEGO Batman: Legacy of the Dark Knight" is a new open-world action adventure vi
# ...

# %%
results[1]["href"]
# Out:
# 'https://www.imdb.com/title/tt37976258/'
